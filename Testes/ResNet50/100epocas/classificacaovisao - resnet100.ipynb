# %% [markdown]
# # Montando o Google Drive

# %%
#conecta com o google drive
from google.colab import drive
drive.mount('/content/drive', timeout_ms=10200000)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importando Bibliotecas

# %%
import os
import random
import time
import platform

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn import metrics
from sklearn.preprocessing import label_binarize
from tqdm import tqdm

import torch
import torchvision
from torchvision import transforms, datasets, utils
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
from torch.utils.data import DataLoader

import seaborn as sns

# %% [markdown]
# # Configurações para reprodutibildade

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # O Dataset

# %%
ds_path = '/home/cip209/Downloads/Júlia/Projeto2Visao-20250114T190416Z-001/Projeto2Visao/dataset'

# %%
# Número de classes
num_classes = 11

# Nomes das classes
class_names = ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightining', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# Tamanho do lote (mini-batch)
batch_size = 64

# Taxa de aprendizado
lr = 0.001

# Número de épocas
epochs = 100 # Usar durante o desenvolvimento
### epochs = 50

# %%
# Treinamento
# Treinamento
data_transforms = transforms.Compose([

    #Estratégias de Data Augmentation (rotação e flips)
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),

    transforms.Resize(size=(224, 224)),
    transforms.ToTensor(),
    # Média e desvio padrão do ImageNet.
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

full_dataset = datasets.ImageFolder(ds_path, transform=data_transforms)

# %%
# Porcentagens para os conjuntos
train_percent = 0.7  # 70% para treino
val_percent = 0.2    # 20% para validação
test_percent = 0.1   # 10% para teste

# Tamanhos dos conjuntos
train_size = int(train_percent * len(full_dataset))
val_size = int(val_percent * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

# Dividindo o dataset
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    full_dataset, [train_size, val_size, test_size]
)

# Número de imagens em cada dataset
print("Tamanhos dos conjuntos:")
print(f"Treino: {len(train_dataset)}")
print(f"Validação: {len(val_dataset)}")
print(f"Teste: {len(test_dataset)}")

# Definindo os dataloaders
train_dataloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size)
test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size)
# Out:
# Tamanhos dos conjuntos:
# Treino: 4803
# Validação: 1372
# Teste: 687

# %%
# Definindo as classes do dataset
classes = train_dataset.dataset.classes

# %%
print(classes)
# Out:
# ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %% [markdown]
# #Seleção do Modelo

# %%
# Carregando o modelo Pré-Treinado
model = models.resnet50(weights='IMAGENET1K_V1')

# Altera o número de neurônios na cadama de saída.
model.fc = nn.Linear(model.fc.in_features, num_classes)

print(str(model))
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=11, bias=True)
# )

# %% [markdown]
# # Verificação de Acesso à GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model.to(device)
# Out:
# Using device: cuda
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=11, bias=True)
# )

# %%
# !nvidia-smi
# Out:
# Tue Jan 14 19:08:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 Ti     Off |   00000000:01:00.0 Off |                  N/A |
# |  0%   43C    P2             16W /  160W |     629MiB /   8188MiB |     11%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1571      G   /usr/lib/xorg/Xorg                            101MiB |
# |    0   N/A  N/A      1788      G   /usr/bin/gnome-shell                          137MiB |
# |    0   N/A  N/A      2959      G   ...irefox/5561/usr/lib/firefox/firefox        140MiB |
# |    0   N/A  N/A      4301      C   /usr/bin/python3                              236MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #Definição da função de perda e do otimizador

# %%
# Função de perda
criterion = nn.CrossEntropyLoss()

# Otimizador
optimizer = optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# #Treinando o Modelo

# %%
"""
#para retomar o  treinamento do último checkpoint salvo (em caso de queda do ambiente de execução)

# Carregar o checkpoint completo
checkpoint = torch.load('checkpoint.pth')

# Reconstruir o modelo e otimizador
model = models.resnet50(pretrained=False)
model.fc = nn.Linear(model.fc.in_features, num_classes)
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)

# Restaurar os estados
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
start_epoch = checkpoint['epoch'] + 1  # Para continuar do próximo
loss = checkpoint['loss']  # Opcional: carregar última perda

# Agora você pode continuar treinando
"""

# Tempo total do treinamento (treinamento e validação)
time_total_start = time.time()

# Lista das perdas (loss) e acurácias (accuracy) de treino para cada época.
train_loss_list = []
train_acc_list = []

# Lista das perdas (loss) e acurácias (accuracy) de validação para cada época.
val_loss_list = []
val_acc_list = []

# Melhor acurácia de validação
best_val_acc = 0.0

# Inicializa a figura para o acompanhamento visual
plt.ion()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

for epoch in range(epochs):
    print(f"Treinamento - epoca {epoch}")
    # TREINAMENTO
    # =========================================================================
    # Inicia contagem de tempo da época
    time_epoch_start = time.time()

    # Habilita o modelo para o modo de treino
    model.train()

    # Perda (loss) nesta época
    loss_epoch_train = 0.0
    # Amostras classificadas corretamente nesta época
    num_hits_epoch_train = 0

    # Iterate along the batches of the TRAINING SET
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        # Zera os parametros do gradiente
        optimizer.zero_grad()

        # FORWARD
        # ------>
        # Habilita o cálculo do gradiente
        torch.set_grad_enabled(True)

        # Saída do modelo para o lote
        outputs = model(inputs)

        # 'outputs' está em porcentagens. Tomar os máximos como resposta.
        preds = torch.argmax(outputs, dim=1)

        # Calcula a perda (loss)
        loss = criterion(outputs, labels)

        # BACKWARD
        # <-------
        loss.backward()

        # Atualiza os parâmetros da rede
        optimizer.step()

        # Atualiza a perda da época
        loss_epoch_train += loss.item() * inputs.size(0)

        # Atualiza o número de amostras classificadas corretamente na época.
        num_hits_epoch_train += torch.sum(preds == labels.data)

    # Perda desta época
    train_loss = loss_epoch_train / train_size
    # Acurácia desta época
    train_acc = num_hits_epoch_train.double() / train_size

    # Store loss and accuracy in lists
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc.cpu().item())  # Move para CPU e converte para float

    # VALIDAÇÃO
    # =========================================================================
    model.eval()
    print(f"Validacao - epoca {epoch}")

    # Pego o número de perda e o número de acertos
    loss_epoch_val = 0.0 # Atual perda
    num_hits_epoch_val = 0 # Número de itens corretos

    # Iterate along the batches of the VALIDATION SET
    with torch.no_grad():
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Gero um tensor cujas linhas representam o tamanho do "batch" do input
            outputs = model(inputs)

            # Retorna a maior predição.
            preds = torch.argmax(outputs, dim=1)

            # Calcula a perda (loss)
            loss = criterion(outputs, labels)

            # Atualiza a perda da época
            loss_epoch_val += loss.item() * inputs.size(0)
            # Atualiza os acertos da época
            num_hits_epoch_val += torch.sum(preds == labels.data)

    # Perda e acurácia do conjunto de validação para esta época
    val_loss = loss_epoch_val / val_size
    val_acc = num_hits_epoch_val.double() / val_size

    # Store loss and accuracy in lists
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc.cpu().item())  # Move para CPU e converte para float

    # Salvar o melhor modelo
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss
        }, '/home/cip209/Downloads/Júlia/Projeto2Visao-20250114T190416Z-001/Projeto2Visao/Testes/ResNet50/100epocas/checkpoint.pth')

    # Tempo total desta época
    time_epoch = time.time() - time_epoch_start

    # PRINTING
    # --------
    print('Epoch {}/{} - TRAIN Loss: {:.4f} TRAIN Acc: {:.4f} - VAL. Loss: {:.4f} VAL. Acc: {:.4f} ({:.4f} seconds)'.format(epoch, epochs - 1, train_loss, train_acc, val_loss, val_acc, time_epoch))


# Tempo total do treinamento
time_total_train = time.time() - time_total_start

# PRINTING
print('\nTreinamento finalizado. ({0}m and {1}s)'.format(int(time_total_train // 60), int(time_total_train % 60)))
# Out:
# Treinamento - epoca 0
# Validacao - epoca 0
# Epoch 0/99 - TRAIN Loss: 1.0262 TRAIN Acc: 0.6677 - VAL. Loss: 0.7978 VAL. Acc: 0.7194 (261.8261 seconds)
# Treinamento - epoca 1
# Validacao - epoca 1
# Epoch 1/99 - TRAIN Loss: 0.6822 TRAIN Acc: 0.7774 - VAL. Loss: 1.1923 VAL. Acc: 0.6574 (66.4245 seconds)
# Treinamento - epoca 2
# Validacao - epoca 2
# Epoch 2/99 - TRAIN Loss: 0.8059 TRAIN Acc: 0.7433 - VAL. Loss: 0.7713 VAL. Acc: 0.7682 (69.1622 seconds)
# Treinamento - epoca 3
# Validacao - epoca 3
# Epoch 3/99 - TRAIN Loss: 0.6367 TRAIN Acc: 0.7970 - VAL. Loss: 0.7650 VAL. Acc: 0.7566 (66.8436 seconds)
# Treinamento - epoca 4
# Validacao - epoca 4
# Epoch 4/99 - TRAIN Loss: 0.5517 TRAIN Acc: 0.8145 - VAL. Loss: 0.5228 VAL. Acc: 0.8294 (68.9723 seconds)
# Treinamento - epoca 5
# Validacao - epoca 5
# Epoch 5/99 - TRAIN Loss: 0.4767 TRAIN Acc: 0.8436 - VAL. Loss: 0.6010 VAL. Acc: 0.7966 (67.0464 seconds)
# Treinamento - epoca 6
# Validacao - epoca 6
# Epoch 6/99 - TRAIN Loss: 0.4231 TRAIN Acc: 0.8543 - VAL. Loss: 0.4990 VAL. Acc: 0.8258 (66.6770 seconds)
# Treinamento - epoca 7
# Validacao - epoca 7
# Epoch 7/99 - TRAIN Loss: 0.3981 TRAIN Acc: 0.8667 - VAL. Loss: 0.5217 VAL. Acc: 0.8411 (69.2753 seconds)
# Treinamento - epoca 8
# Validacao - epoca 8
# Epoch 8/99 - TRAIN Loss: 0.3987 TRAIN Acc: 0.8653 - VAL. Loss: 0.5132 VAL. Acc: 0.8258 (67.1294 seconds)
# Treinamento - epoca 9
# Validacao - epoca 9
# Epoch 9/99 - TRAIN Loss: 0.3924 TRAIN Acc: 0.8670 - VAL. Loss: 0.5443 VAL. Acc: 0.8294 (66.5577 seconds)
# Treinamento - epoca 10
# Validacao - epoca 10
# Epoch 10/99 - TRAIN Loss: 0.4422 TRAIN Acc: 0.8580 - VAL. Loss: 0.4408 VAL. Acc: 0.8571 (69.1546 seconds)
# Treinamento - epoca 11
# Validacao - epoca 11
# Epoch 11/99 - TRAIN Loss: 0.3908 TRAIN Acc: 0.8682 - VAL. Loss: 0.5388 VAL. Acc: 0.8345 (66.0860 seconds)
# Treinamento - epoca 12
# Validacao - epoca 12
# Epoch 12/99 - TRAIN Loss: 0.4531 TRAIN Acc: 0.8497 - VAL. Loss: 0.5559 VAL. Acc: 0.8178 (66.2366 seconds)
# Treinamento - epoca 13
# Validacao - epoca 13
# Epoch 13/99 - TRAIN Loss: 0.3494 TRAIN Acc: 0.8788 - VAL. Loss: 0.8203 VAL. Acc: 0.7332 (67.2706 seconds)
# Treinamento - epoca 14
# Validacao - epoca 14
# Epoch 14/99 - TRAIN Loss: 0.4882 TRAIN Acc: 0.8401 - VAL. Loss: 0.7577 VAL. Acc: 0.7923 (66.9832 seconds)
# Treinamento - epoca 15
# Validacao - epoca 15
# Epoch 15/99 - TRAIN Loss: 0.3712 TRAIN Acc: 0.8738 - VAL. Loss: 0.4536 VAL. Acc: 0.8513 (66.5981 seconds)
# Treinamento - epoca 16
# Validacao - epoca 16
# Epoch 16/99 - TRAIN Loss: 0.3144 TRAIN Acc: 0.8915 - VAL. Loss: 0.4765 VAL. Acc: 0.8535 (67.0509 seconds)
# Treinamento - epoca 17
# Validacao - epoca 17
# Epoch 17/99 - TRAIN Loss: 0.2549 TRAIN Acc: 0.9111 - VAL. Loss: 0.4717 VAL. Acc: 0.8528 (66.6138 seconds)
# Treinamento - epoca 18
# Validacao - epoca 18
# Epoch 18/99 - TRAIN Loss: 0.3271 TRAIN Acc: 0.8842 - VAL. Loss: 0.4955 VAL. Acc: 0.8418 (66.4809 seconds)
# Treinamento - epoca 19
# Validacao - epoca 19
# Epoch 19/99 - TRAIN Loss: 0.2654 TRAIN Acc: 0.9073 - VAL. Loss: 0.3599 VAL. Acc: 0.8892 (68.7706 seconds)
# Treinamento - epoca 20
# Validacao - epoca 20
# Epoch 20/99 - TRAIN Loss: 0.2286 TRAIN Acc: 0.9217 - VAL. Loss: 0.5446 VAL. Acc: 0.8433 (66.4821 seconds)
# Treinamento - epoca 21
# Validacao - epoca 21
# Epoch 21/99 - TRAIN Loss: 0.2895 TRAIN Acc: 0.9007 - VAL. Loss: 0.6920 VAL. Acc: 0.7988 (66.5469 seconds)
# Treinamento - epoca 22
# Validacao - epoca 22
# Epoch 22/99 - TRAIN Loss: 0.4040 TRAIN Acc: 0.8632 - VAL. Loss: 0.4754 VAL. Acc: 0.8520 (66.1263 seconds)
# Treinamento - epoca 23
# Validacao - epoca 23
# Epoch 23/99 - TRAIN Loss: 0.2410 TRAIN Acc: 0.9169 - VAL. Loss: 0.3422 VAL. Acc: 0.8834 (66.7143 seconds)
# Treinamento - epoca 24
# Validacao - epoca 24
# Epoch 24/99 - TRAIN Loss: 0.2070 TRAIN Acc: 0.9309 - VAL. Loss: 0.4705 VAL. Acc: 0.8542 (66.3356 seconds)
# Treinamento - epoca 25
# Validacao - epoca 25
# Epoch 25/99 - TRAIN Loss: 0.3001 TRAIN Acc: 0.8999 - VAL. Loss: 0.4086 VAL. Acc: 0.8586 (65.8666 seconds)
# Treinamento - epoca 26
# Validacao - epoca 26
# Epoch 26/99 - TRAIN Loss: 0.2021 TRAIN Acc: 0.9269 - VAL. Loss: 0.3867 VAL. Acc: 0.8761 (65.6191 seconds)
# Treinamento - epoca 27
# Validacao - epoca 27
# Epoch 27/99 - TRAIN Loss: 0.1879 TRAIN Acc: 0.9377 - VAL. Loss: 0.8596 VAL. Acc: 0.7733 (65.5389 seconds)
# Treinamento - epoca 28
# Validacao - epoca 28
# Epoch 28/99 - TRAIN Loss: 0.2663 TRAIN Acc: 0.9101 - VAL. Loss: 0.5554 VAL. Acc: 0.8477 (65.7385 seconds)
# Treinamento - epoca 29
# Validacao - epoca 29
# Epoch 29/99 - TRAIN Loss: 0.2280 TRAIN Acc: 0.9198 - VAL. Loss: 0.4828 VAL. Acc: 0.8528 (65.8206 seconds)
# Treinamento - epoca 30
# Validacao - epoca 30
# Epoch 30/99 - TRAIN Loss: 0.2107 TRAIN Acc: 0.9269 - VAL. Loss: 0.3777 VAL. Acc: 0.8812 (65.8588 seconds)
# Treinamento - epoca 31
# Validacao - epoca 31
# Epoch 31/99 - TRAIN Loss: 0.2605 TRAIN Acc: 0.9198 - VAL. Loss: 0.5153 VAL. Acc: 0.8550 (65.4960 seconds)
# Treinamento - epoca 32
# Validacao - epoca 32
# Epoch 32/99 - TRAIN Loss: 0.2750 TRAIN Acc: 0.9021 - VAL. Loss: 0.4405 VAL. Acc: 0.8571 (65.5469 seconds)
# Treinamento - epoca 33
# Validacao - epoca 33
# Epoch 33/99 - TRAIN Loss: 0.2299 TRAIN Acc: 0.9228 - VAL. Loss: 0.4182 VAL. Acc: 0.8797 (65.5614 seconds)
# Treinamento - epoca 34
# Validacao - epoca 34
# Epoch 34/99 - TRAIN Loss: 0.2362 TRAIN Acc: 0.9232 - VAL. Loss: 0.4887 VAL. Acc: 0.8506 (65.6281 seconds)
# Treinamento - epoca 35
# Validacao - epoca 35
# Epoch 35/99 - TRAIN Loss: 0.2312 TRAIN Acc: 0.9171 - VAL. Loss: 0.4353 VAL. Acc: 0.8746 (65.7302 seconds)
# Treinamento - epoca 36
# Validacao - epoca 36
# Epoch 36/99 - TRAIN Loss: 0.2251 TRAIN Acc: 0.9238 - VAL. Loss: 0.5018 VAL. Acc: 0.8579 (65.1698 seconds)
# Treinamento - epoca 37
# Validacao - epoca 37
# Epoch 37/99 - TRAIN Loss: 0.2414 TRAIN Acc: 0.9194 - VAL. Loss: 0.3775 VAL. Acc: 0.8754 (65.7562 seconds)
# Treinamento - epoca 38
# Validacao - epoca 38
# Epoch 38/99 - TRAIN Loss: 0.1453 TRAIN Acc: 0.9502 - VAL. Loss: 0.3853 VAL. Acc: 0.8834 (65.4617 seconds)
# Treinamento - epoca 39
# Validacao - epoca 39
# Epoch 39/99 - TRAIN Loss: 0.1283 TRAIN Acc: 0.9542 - VAL. Loss: 0.4756 VAL. Acc: 0.8695 (65.3994 seconds)
# Treinamento - epoca 40
# Validacao - epoca 40
# Epoch 40/99 - TRAIN Loss: 0.2553 TRAIN Acc: 0.9109 - VAL. Loss: 0.4203 VAL. Acc: 0.8710 (65.5952 seconds)
# Treinamento - epoca 41
# Validacao - epoca 41
# Epoch 41/99 - TRAIN Loss: 0.1516 TRAIN Acc: 0.9461 - VAL. Loss: 0.3373 VAL. Acc: 0.8943 (67.9342 seconds)
# Treinamento - epoca 42
# Validacao - epoca 42
# Epoch 42/99 - TRAIN Loss: 0.1140 TRAIN Acc: 0.9615 - VAL. Loss: 0.4545 VAL. Acc: 0.8739 (66.5123 seconds)
# Treinamento - epoca 43
# Validacao - epoca 43
# Epoch 43/99 - TRAIN Loss: 0.2372 TRAIN Acc: 0.9203 - VAL. Loss: 0.4283 VAL. Acc: 0.8710 (65.6246 seconds)
# Treinamento - epoca 44
# Validacao - epoca 44
# Epoch 44/99 - TRAIN Loss: 0.1511 TRAIN Acc: 0.9484 - VAL. Loss: 0.4544 VAL. Acc: 0.8710 (65.4863 seconds)
# Treinamento - epoca 45
# Validacao - epoca 45
# Epoch 45/99 - TRAIN Loss: 0.2013 TRAIN Acc: 0.9284 - VAL. Loss: 0.4366 VAL. Acc: 0.8703 (76.6092 seconds)
# Treinamento - epoca 46
# Validacao - epoca 46
# Epoch 46/99 - TRAIN Loss: 0.2893 TRAIN Acc: 0.9026 - VAL. Loss: 0.4477 VAL. Acc: 0.8601 (65.6984 seconds)
# Treinamento - epoca 47
# Validacao - epoca 47
# Epoch 47/99 - TRAIN Loss: 0.2541 TRAIN Acc: 0.9107 - VAL. Loss: 0.4484 VAL. Acc: 0.8637 (65.1908 seconds)
# Treinamento - epoca 48
# Validacao - epoca 48
# Epoch 48/99 - TRAIN Loss: 0.2267 TRAIN Acc: 0.9240 - VAL. Loss: 0.5004 VAL. Acc: 0.8673 (65.6900 seconds)
# Treinamento - epoca 49
# Validacao - epoca 49
# Epoch 49/99 - TRAIN Loss: 0.1404 TRAIN Acc: 0.9509 - VAL. Loss: 0.4914 VAL. Acc: 0.8601 (65.0766 seconds)
# Treinamento - epoca 50
# Validacao - epoca 50
# Epoch 50/99 - TRAIN Loss: 0.1763 TRAIN Acc: 0.9382 - VAL. Loss: 0.5616 VAL. Acc: 0.8550 (65.3761 seconds)
# Treinamento - epoca 51
# Validacao - epoca 51
# Epoch 51/99 - TRAIN Loss: 0.2719 TRAIN Acc: 0.9142 - VAL. Loss: 0.3888 VAL. Acc: 0.8834 (65.2371 seconds)
# Treinamento - epoca 52
# Validacao - epoca 52
# Epoch 52/99 - TRAIN Loss: 0.1302 TRAIN Acc: 0.9567 - VAL. Loss: 0.4269 VAL. Acc: 0.8856 (64.9016 seconds)
# Treinamento - epoca 53
# Validacao - epoca 53
# Epoch 53/99 - TRAIN Loss: 0.0948 TRAIN Acc: 0.9692 - VAL. Loss: 0.4494 VAL. Acc: 0.8761 (65.1486 seconds)
# Treinamento - epoca 54
# Validacao - epoca 54
# Epoch 54/99 - TRAIN Loss: 0.3201 TRAIN Acc: 0.8969 - VAL. Loss: 0.4167 VAL. Acc: 0.8761 (64.8337 seconds)
# Treinamento - epoca 55
# Validacao - epoca 55
# Epoch 55/99 - TRAIN Loss: 0.1284 TRAIN Acc: 0.9577 - VAL. Loss: 0.4600 VAL. Acc: 0.8688 (64.7678 seconds)
# Treinamento - epoca 56
# Validacao - epoca 56
# Epoch 56/99 - TRAIN Loss: 0.1911 TRAIN Acc: 0.9363 - VAL. Loss: 0.4085 VAL. Acc: 0.8790 (65.1617 seconds)
# Treinamento - epoca 57
# Validacao - epoca 57
# Epoch 57/99 - TRAIN Loss: 0.1612 TRAIN Acc: 0.9434 - VAL. Loss: 0.4186 VAL. Acc: 0.8615 (65.1883 seconds)
# Treinamento - epoca 58
# Validacao - epoca 58
# Epoch 58/99 - TRAIN Loss: 0.2468 TRAIN Acc: 0.9223 - VAL. Loss: 0.3989 VAL. Acc: 0.8754 (65.0338 seconds)
# Treinamento - epoca 59
# Validacao - epoca 59
# Epoch 59/99 - TRAIN Loss: 0.1188 TRAIN Acc: 0.9590 - VAL. Loss: 0.4447 VAL. Acc: 0.8827 (65.4524 seconds)
# Treinamento - epoca 60
# Validacao - epoca 60
# Epoch 60/99 - TRAIN Loss: 0.1540 TRAIN Acc: 0.9459 - VAL. Loss: 0.4416 VAL. Acc: 0.8710 (64.7892 seconds)
# Treinamento - epoca 61
# Validacao - epoca 61
# Epoch 61/99 - TRAIN Loss: 0.1335 TRAIN Acc: 0.9517 - VAL. Loss: 0.4854 VAL. Acc: 0.8615 (65.2917 seconds)
# Treinamento - epoca 62
# Validacao - epoca 62
# Epoch 62/99 - TRAIN Loss: 0.0803 TRAIN Acc: 0.9729 - VAL. Loss: 0.5729 VAL. Acc: 0.8717 (65.0465 seconds)
# Treinamento - epoca 63
# Validacao - epoca 63
# Epoch 63/99 - TRAIN Loss: 0.0724 TRAIN Acc: 0.9754 - VAL. Loss: 0.4451 VAL. Acc: 0.8958 (67.3456 seconds)
# Treinamento - epoca 64
# Validacao - epoca 64
# Epoch 64/99 - TRAIN Loss: 0.1382 TRAIN Acc: 0.9507 - VAL. Loss: 0.4229 VAL. Acc: 0.8885 (64.9405 seconds)
# Treinamento - epoca 65
# Validacao - epoca 65
# Epoch 65/99 - TRAIN Loss: 0.0934 TRAIN Acc: 0.9679 - VAL. Loss: 0.5336 VAL. Acc: 0.8681 (64.9438 seconds)
# Treinamento - epoca 66
# Validacao - epoca 66
# Epoch 66/99 - TRAIN Loss: 0.1366 TRAIN Acc: 0.9534 - VAL. Loss: 0.4804 VAL. Acc: 0.8761 (64.8839 seconds)
# Treinamento - epoca 67
# Validacao - epoca 67
# Epoch 67/99 - TRAIN Loss: 0.0798 TRAIN Acc: 0.9740 - VAL. Loss: 0.4653 VAL. Acc: 0.8834 (65.3184 seconds)
# Treinamento - epoca 68
# Validacao - epoca 68
# Epoch 68/99 - TRAIN Loss: 0.0729 TRAIN Acc: 0.9742 - VAL. Loss: 0.4383 VAL. Acc: 0.8950 (65.0365 seconds)
# Treinamento - epoca 69
# Validacao - epoca 69
# Epoch 69/99 - TRAIN Loss: 0.0619 TRAIN Acc: 0.9783 - VAL. Loss: 0.4581 VAL. Acc: 0.8812 (65.9755 seconds)
# Treinamento - epoca 70
# Validacao - epoca 70
# Epoch 70/99 - TRAIN Loss: 0.0617 TRAIN Acc: 0.9804 - VAL. Loss: 0.4577 VAL. Acc: 0.8783 (65.8028 seconds)
# Treinamento - epoca 71
# Validacao - epoca 71
# Epoch 71/99 - TRAIN Loss: 0.1252 TRAIN Acc: 0.9594 - VAL. Loss: 0.4567 VAL. Acc: 0.8739 (65.5149 seconds)
# Treinamento - epoca 72
# Validacao - epoca 72
# Epoch 72/99 - TRAIN Loss: 0.1200 TRAIN Acc: 0.9588 - VAL. Loss: 0.4383 VAL. Acc: 0.8848 (65.7289 seconds)
# Treinamento - epoca 73
# Validacao - epoca 73
# Epoch 73/99 - TRAIN Loss: 0.0862 TRAIN Acc: 0.9709 - VAL. Loss: 0.4336 VAL. Acc: 0.8899 (65.8913 seconds)
# Treinamento - epoca 74
# Validacao - epoca 74
# Epoch 74/99 - TRAIN Loss: 0.0516 TRAIN Acc: 0.9827 - VAL. Loss: 0.4383 VAL. Acc: 0.8943 (65.8009 seconds)
# Treinamento - epoca 75
# Validacao - epoca 75
# Epoch 75/99 - TRAIN Loss: 0.1853 TRAIN Acc: 0.9348 - VAL. Loss: 1.0746 VAL. Acc: 0.8120 (65.5772 seconds)
# Treinamento - epoca 76
# Validacao - epoca 76
# Epoch 76/99 - TRAIN Loss: 0.2215 TRAIN Acc: 0.9288 - VAL. Loss: 0.4846 VAL. Acc: 0.8724 (65.8320 seconds)
# Treinamento - epoca 77
# Validacao - epoca 77
# Epoch 77/99 - TRAIN Loss: 0.1382 TRAIN Acc: 0.9517 - VAL. Loss: 0.4203 VAL. Acc: 0.8848 (65.9091 seconds)
# Treinamento - epoca 78
# Validacao - epoca 78
# Epoch 78/99 - TRAIN Loss: 0.0897 TRAIN Acc: 0.9675 - VAL. Loss: 0.6471 VAL. Acc: 0.8550 (65.6037 seconds)
# Treinamento - epoca 79
# Validacao - epoca 79
# Epoch 79/99 - TRAIN Loss: 0.2569 TRAIN Acc: 0.9123 - VAL. Loss: 0.4172 VAL. Acc: 0.8863 (65.4882 seconds)
# Treinamento - epoca 80
# Validacao - epoca 80
# Epoch 80/99 - TRAIN Loss: 0.1022 TRAIN Acc: 0.9661 - VAL. Loss: 0.4035 VAL. Acc: 0.8914 (65.5091 seconds)
# Treinamento - epoca 81
# Validacao - epoca 81
# Epoch 81/99 - TRAIN Loss: 0.0665 TRAIN Acc: 0.9779 - VAL. Loss: 0.4814 VAL. Acc: 0.8899 (65.9929 seconds)
# Treinamento - epoca 82
# Validacao - epoca 82
# Epoch 82/99 - TRAIN Loss: 0.1484 TRAIN Acc: 0.9517 - VAL. Loss: 0.4513 VAL. Acc: 0.8863 (66.0020 seconds)
# Treinamento - epoca 83
# Validacao - epoca 83
# Epoch 83/99 - TRAIN Loss: 0.0636 TRAIN Acc: 0.9758 - VAL. Loss: 0.5321 VAL. Acc: 0.8761 (66.1529 seconds)
# Treinamento - epoca 84
# Validacao - epoca 84
# Epoch 84/99 - TRAIN Loss: 0.2451 TRAIN Acc: 0.9217 - VAL. Loss: 0.6137 VAL. Acc: 0.8448 (65.5929 seconds)
# Treinamento - epoca 85
# Validacao - epoca 85
# Epoch 85/99 - TRAIN Loss: 0.1666 TRAIN Acc: 0.9415 - VAL. Loss: 0.4928 VAL. Acc: 0.8746 (66.3120 seconds)
# Treinamento - epoca 86
# Validacao - epoca 86
# Epoch 86/99 - TRAIN Loss: 0.1458 TRAIN Acc: 0.9479 - VAL. Loss: 0.4434 VAL. Acc: 0.8797 (65.7977 seconds)
# Treinamento - epoca 87
# Validacao - epoca 87
# Epoch 87/99 - TRAIN Loss: 0.0652 TRAIN Acc: 0.9798 - VAL. Loss: 0.4023 VAL. Acc: 0.8878 (67.3960 seconds)
# Treinamento - epoca 88
# Validacao - epoca 88
# Epoch 88/99 - TRAIN Loss: 0.1362 TRAIN Acc: 0.9534 - VAL. Loss: 0.4311 VAL. Acc: 0.8921 (66.2069 seconds)
# Treinamento - epoca 89
# Validacao - epoca 89
# Epoch 89/99 - TRAIN Loss: 0.0619 TRAIN Acc: 0.9819 - VAL. Loss: 0.4221 VAL. Acc: 0.8965 (68.0950 seconds)
# Treinamento - epoca 90
# Validacao - epoca 90
# Epoch 90/99 - TRAIN Loss: 0.0581 TRAIN Acc: 0.9798 - VAL. Loss: 0.5007 VAL. Acc: 0.8805 (66.7717 seconds)
# Treinamento - epoca 91
# Validacao - epoca 91
# Epoch 91/99 - TRAIN Loss: 0.1345 TRAIN Acc: 0.9565 - VAL. Loss: 0.5102 VAL. Acc: 0.8550 (65.9756 seconds)
# Treinamento - epoca 92
# Validacao - epoca 92
# Epoch 92/99 - TRAIN Loss: 0.0907 TRAIN Acc: 0.9704 - VAL. Loss: 0.5385 VAL. Acc: 0.8812 (65.7516 seconds)
# Treinamento - epoca 93
# Validacao - epoca 93
# Epoch 93/99 - TRAIN Loss: 0.0531 TRAIN Acc: 0.9817 - VAL. Loss: 0.4593 VAL. Acc: 0.8907 (65.0263 seconds)
# Treinamento - epoca 94
# Validacao - epoca 94
# Epoch 94/99 - TRAIN Loss: 0.2624 TRAIN Acc: 0.9155 - VAL. Loss: 0.5095 VAL. Acc: 0.8673 (65.1624 seconds)
# Treinamento - epoca 95
# Validacao - epoca 95
# Epoch 95/99 - TRAIN Loss: 0.1388 TRAIN Acc: 0.9532 - VAL. Loss: 0.4277 VAL. Acc: 0.8848 (66.2353 seconds)
# Treinamento - epoca 96
# Validacao - epoca 96
# Epoch 96/99 - TRAIN Loss: 0.2589 TRAIN Acc: 0.9163 - VAL. Loss: 0.4505 VAL. Acc: 0.8703 (64.9794 seconds)
# Treinamento - epoca 97
# Validacao - epoca 97
# Epoch 97/99 - TRAIN Loss: 0.0838 TRAIN Acc: 0.9729 - VAL. Loss: 0.3678 VAL. Acc: 0.9045 (68.6389 seconds)
# Treinamento - epoca 98
# Validacao - epoca 98
# Epoch 98/99 - TRAIN Loss: 0.0816 TRAIN Acc: 0.9729 - VAL. Loss: 0.5538 VAL. Acc: 0.8666 (65.5179 seconds)
# Treinamento - epoca 99
# Validacao - epoca 99
# Epoch 99/99 - TRAIN Loss: 0.0671 TRAIN Acc: 0.9779 - VAL. Loss: 0.5187 VAL. Acc: 0.8710 (66.5929 seconds)
#
# Treinamento finalizado. (113m and 32s)

# %% [markdown]
# #Analisando o Treinamento

# %%
# Lista com os índices das épocas. [0, 1, ... num_epochs - 1]
epochs_list = list(range(len(train_loss_list)))

# Títulos
loss_title = f'Loss over {len(epochs_list)} Epochs'
acc_title = f'Accuracy over {len(epochs_list)} Epochs'

# Plot - Loss and Accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot - Loss
ax1.set_title(loss_title)
ax1.plot(epochs_list, train_loss_list, c='magenta', ls='--', label='Train Loss', fillstyle='none')
ax1.plot(epochs_list, val_loss_list, c='green', ls='--', label='Val. Loss', fillstyle='none')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='best')
ax1.grid(True)

# Plot - Accuracy
ax2.set_title(acc_title)
ax2.plot(epochs_list, train_acc_list, c='magenta', ls='-', label='Train Accuracy', fillstyle='none')
ax2.plot(epochs_list, val_acc_list, c='green', ls='-', label='Val. Accuracy', fillstyle='none')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend(loc='best')
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Avaliando o Modelo

# %%
# Carregando o modelo Pré-Treinado
model = models.resnet50(pretrained=False)

# Altera o número de neurônios na cadama de saída.
model.fc = nn.Linear(model.fc.in_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model.to(device)

# Carregar o melhor modelo salvo
checkpoint = torch.load('/home/cip209/Downloads/Júlia/Projeto2Visao-20250114T190416Z-001/Projeto2Visao/Testes/ResNet50/100epocas/checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
start_epoch = checkpoint['epoch']

print(f"Melhor Época {start_epoch}")


model.eval()

# Lista com as classes reais e classes preditas
true_test_list = []
pred_test_list = []
# Lista com as probabilidades
prob_test_list = []

# Iterate along the batches of the TEST SET
with torch.no_grad():
    for img_list, labelList in test_dataloader:
        img_list, labelList = img_list.to(device), labelList.to(device)

        # -----> FORWARD
        # Saída do modelo
        outputs = model(img_list)

        # Predição
        preds = torch.argmax(outputs, dim=1)

        # Calcula probabilidades
        outputs_prob = nn.functional.softmax(outputs, dim=1)
        prob_test_batch = outputs_prob.cpu().numpy()

        # Classes reais (true) e classes preditas (pred) para este lote.
        true_test_batch = labelList.cpu().numpy()
        pred_test_batch = preds.cpu().numpy()

        # Adiciona os resultados às listas
        true_test_list.extend(true_test_batch)
        pred_test_list.extend(pred_test_batch)
        prob_test_list.extend(prob_test_batch)
# Out:
# /home/cip209/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/cip209/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Using device: cuda
# /tmp/ipykernel_4301/1241372972.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/home/cip209/Downloads/Júlia/Projeto2Visao-20250114T190416Z-001/Projeto2Visao/Testes/ResNet50/100epocas/checkpoint.pth')
# Melhor Época 97

# %% [markdown]
# # Matrix de Confusão e Relatório de Classificação

# %%
# Matriz de Confusão
conf_mat_test = metrics.confusion_matrix(true_test_list, pred_test_list)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat_test, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matriz de Confusão')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report - Scikit-learn
class_rep_test = metrics.classification_report(true_test_list, pred_test_list,
                                              target_names=class_names, output_dict = True, #dicionário para uso pessoal
                                              digits=4,
                                              zero_division=0)
print('\nClass. report (test)')
print(class_rep_test)

print("Relatório de Classificação por Classe:")
print(metrics.classification_report(true_test_list, pred_test_list,
                                    target_names=class_names,
                                    digits=4, zero_division=0))

# Accuracy
acc_test = metrics.accuracy_score(true_test_list, pred_test_list)
print('\n\Test Acc.: {:.4f}'.format(acc_test))

# Função para mostrar imagens
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.axis('off')

# Obter um lote de dados de teste
inputs, classes = next(iter(test_dataloader))

# Fazer previsões
outputs = model(inputs.to(device))
_, preds = torch.max(outputs, 1)

# Plotar as imagens e suas previsões
plt.figure(figsize=(15, 10))
for i in range(min(len(inputs), 8)):  # Mostrar até 8 imagens
    ax = plt.subplot(2, 4, i + 1)
    imshow(inputs[i], title=f'Pred: {class_names[preds[i]]}\nTrue: {class_names[classes[i]]}')
plt.tight_layout()
plt.show()


#POR CLASSE
#extração de métricas
precisoes=[class_rep_test[cls]['precision'] for cls in class_names]
recalls=[class_rep_test[cls]['recall'] for cls in class_names]
f1_scores=[class_rep_test[cls]['f1-score'] for cls in class_names]

#para plotagem
x = range(len(class_names))
width = 0.2 #largura barras

plt.figure(figsize=(12, 6))
plt.bar(x, precisoes, width, label='Precisão', color='blue')
plt.bar([i + width for i in x], recalls, width, label='Recall', color='green')
plt.bar([i + 2 * width for i in x], f1_scores, width, label='F1-Score', color='orange')

#dos eixos
plt.xlabel('Classes')
plt.ylabel('Métricas')
plt.title('Métricas por Classe')
plt.xticks([i + width for i in x], class_names, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

#CURVA ROC
true_binarized = label_binarize(true_test_list, classes=list(range(num_classes)))

#variaveis para curvas e areas
fpr = dict()
tpr = dict()
roc_auc = dict()

#calcular curva roc e auc para cada classe
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(true_binarized[:, i], [p[i] for p in prob_test_list])
    roc_auc[i] = auc(fpr[i], tpr[i])

#calcular marcro-average roc e auc
fpr["macro"], tpr["macro"], _=roc_curve(
    true_binarized.ravel(), [p for probs in prob_test_list for p in probs]
)

roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#plotar curvas roc para cada classe
plt.figure(figsize=(10, 8))
colors = plt.cm.get_cmap("tab10", num_classes)

"""
for i in range(num_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        color=colors(i),
        lw=2,
        label=f"Classe {class_names[i]} (AUC = {roc_auc[i]:0.2f})",
    )
"""

# Adicionar curva macro-average
plt.plot(
    fpr["macro"],
    tpr["macro"],
    color="darkorange",
    linestyle="--",
    lw=3,
    label=f"Macro-average (AUC = {roc_auc['macro']:0.2f})",
)

# Configurar o gráfico
plt.plot([0, 1], [0, 1], color="navy", linestyle="--", lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curvas ROC para cada classe")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# Class. report (test)
# {'dew': {'precision': 0.9230769230769231, 'recall': 0.972972972972973, 'f1-score': 0.9473684210526315, 'support': 74.0}, 'fogsmog': {'precision': 0.9230769230769231, 'recall': 0.9, 'f1-score': 0.9113924050632911, 'support': 80.0}, 'frost': {'precision': 0.8857142857142857, 'recall': 0.7209302325581395, 'f1-score': 0.7948717948717948, 'support': 43.0}, 'glaze': {'precision': 0.6666666666666666, 'recall': 0.7058823529411765, 'f1-score': 0.6857142857142857, 'support': 51.0}, 'hail': {'precision': 0.96875, 'recall': 0.9117647058823529, 'f1-score': 0.9393939393939394, 'support': 68.0}, 'lightining': {'precision': 0.9523809523809523, 'recall': 1.0, 'f1-score': 0.975609756097561, 'support': 40.0}, 'rain': {'precision': 0.9411764705882353, 'recall': 0.8421052631578947, 'f1-score': 0.8888888888888888, 'support': 57.0}, 'rainbow': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 29.0}, 'rime': {'precision': 0.9026548672566371, 'recall': 0.918918918918919, 'f1-score': 0.9107142857142857, 'support': 111.0}, 'sandstorm': {'precision': 0.8902439024390244, 'recall': 0.9733333333333334, 'f1-score': 0.9299363057324841, 'support': 75.0}, 'snow': {'precision': 0.7540983606557377, 'recall': 0.7796610169491526, 'f1-score': 0.7666666666666667, 'support': 59.0}, 'accuracy': 0.8893740902474527, 'macro avg': {'precision': 0.8916217592595804, 'recall': 0.8841426178830857, 'f1-score': 0.8864142499268937, 'support': 687.0}, 'weighted avg': {'precision': 0.8912833239962591, 'recall': 0.8893740902474527, 'f1-score': 0.8890906231161371, 'support': 687.0}}
# Relatório de Classificação por Classe:
#               precision    recall  f1-score   support
#
#          dew     0.9231    0.9730    0.9474        74
#      fogsmog     0.9231    0.9000    0.9114        80
#        frost     0.8857    0.7209    0.7949        43
#        glaze     0.6667    0.7059    0.6857        51
#         hail     0.9688    0.9118    0.9394        68
#   lightining     0.9524    1.0000    0.9756        40
#         rain     0.9412    0.8421    0.8889        57
#      rainbow     1.0000    1.0000    1.0000        29
#         rime     0.9027    0.9189    0.9107       111
#    sandstorm     0.8902    0.9733    0.9299        75
#         snow     0.7541    0.7797    0.7667        59
#
#     accuracy                         0.8894       687
#    macro avg     0.8916    0.8841    0.8864       687
# weighted avg     0.8913    0.8894    0.8891       687
#
#
# \Test Acc.: 0.8894

# %% [markdown]
# #Créditos

# %%
https://github.com/joaofmari/awesome-computer-vision-deep-learning
