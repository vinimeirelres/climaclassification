# %% [markdown]
# # Montando o Google Drive

# %%
#conecta com o google drive
from google.colab import drive
drive.mount('/content/drive', timeout_ms=10200000)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importando Bibliotecas

# %%
import os
import random
import time
import platform

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn import metrics
from sklearn.preprocessing import label_binarize
from tqdm import tqdm

import torch
import torchvision
from torchvision import transforms, datasets, utils
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
from torch.utils.data import DataLoader

import seaborn as sns

# %% [markdown]
# # Configurações para reprodutibildade

# %%
SEED = 42

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)

torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # O Dataset

# %%
ds_path = '/home/cip209/Downloads/Vinícius/Projeto2Visao/dataset'

# %%
# Número de classes
num_classes = 11

# Nomes das classes
class_names = ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightining', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# Tamanho do lote (mini-batch)
batch_size = 64

# Taxa de aprendizado
lr = 0.001

# Número de épocas
epochs = 100
### epochs = 50

# %%
# Treinamento
data_transforms = transforms.Compose([

    #Estratégias de Data Augmentation (rotação e flips)
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),

    transforms.Resize(size=(224, 224)),
    transforms.ToTensor(),
    # Média e desvio padrão do ImageNet.
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

full_dataset = datasets.ImageFolder(ds_path, transform=data_transforms)

# %%
# Porcentagens para os conjuntos
train_percent = 0.7  # 70% para treino
val_percent = 0.2    # 20% para validação
test_percent = 0.1   # 10% para teste

# Tamanhos dos conjuntos
train_size = int(train_percent * len(full_dataset))
val_size = int(val_percent * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

# Dividindo o dataset
train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    full_dataset, [train_size, val_size, test_size]
)

# Número de imagens em cada dataset
print("Tamanhos dos conjuntos:")
print(f"Treino: {len(train_dataset)}")
print(f"Validação: {len(val_dataset)}")
print(f"Teste: {len(test_dataset)}")

# Definindo os dataloaders
train_dataloader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=batch_size)
test_dataloader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size)
# Out:
# Tamanhos dos conjuntos:
# Treino: 4803
# Validação: 1372
# Teste: 687

# %%
# Definindo as classes do dataset
classes = train_dataset.dataset.classes

# %%
print(classes)
# Out:
# ['dew', 'fogsmog', 'frost', 'glaze', 'hail', 'lightning', 'rain', 'rainbow', 'rime', 'sandstorm', 'snow']

# %% [markdown]
# #Seleção do Modelo

# %%
# Carregando o modelo Pré-Treinado
model = models.alexnet(weights='IMAGENET1K_V1')

# Altera o número de neurônios na cadama de saída.
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)

print(str(model))
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=11, bias=True)
#   )
# )

# %% [markdown]
# # Verificação de Acesso à GPU

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model.to(device)
# Out:
# Using device: cuda
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=11, bias=True)
#   )
# )

# %%
# !nvidia-smi
# Out:
# Tue Jan 14 18:28:25 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.120                Driver Version: 550.120        CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060 Ti     Off |   00000000:01:00.0  On |                  N/A |
# |  0%   51C    P2             26W /  160W |    5050MiB /   8188MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A      1642      G   /usr/lib/xorg/Xorg                             70MiB |
# |    0   N/A  N/A      1810      G   /usr/bin/gnome-shell                           22MiB |
# |    0   N/A  N/A      2380      G   ...irefox/5437/usr/lib/firefox/firefox        160MiB |
# |    0   N/A  N/A      4423      C   /usr/bin/python3                             2318MiB |
# |    0   N/A  N/A      8322      C   /usr/bin/python3                             2460MiB |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# #Definição da função de perda e do otimizador

# %%
# Função de perda
criterion = nn.CrossEntropyLoss()

# Otimizador
optimizer = optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# #Treinando o Modelo

# %%
"""
#para retomar o  treinamento do último checkpoint salvo (em caso de queda do ambiente de execução)

# Carregar o checkpoint completo
checkpoint = torch.load('checkpoint.pth')

# Reconstruir o modelo e otimizador
model = models.alexnet(pretrained=False)
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)
model.to(device)

optimizer = optim.Adam(model.parameters(), lr=lr)

# Restaurar os estados
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
start_epoch = checkpoint['epoch'] + 1  # Para continuar do próximo
loss = checkpoint['loss']  # Opcional: carregar última perda

# Agora você pode continuar treinando
"""

# Tempo total do treinamento (treinamento e validação)
time_total_start = time.time()

# Lista das perdas (loss) e acurácias (accuracy) de treino para cada época.
train_loss_list = []
train_acc_list = []

# Lista das perdas (loss) e acurácias (accuracy) de validação para cada época.
val_loss_list = []
val_acc_list = []

# Melhor acurácia de validação
best_val_acc = 0.0

# Inicializa a figura para o acompanhamento visual
plt.ion()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

for epoch in range(epochs):
    print(f"Treinamento - epoca {epoch}")
    # TREINAMENTO
    # =========================================================================
    # Inicia contagem de tempo da época
    time_epoch_start = time.time()

    # Habilita o modelo para o modo de treino
    model.train()

    # Perda (loss) nesta época
    loss_epoch_train = 0.0
    # Amostras classificadas corretamente nesta época
    num_hits_epoch_train = 0

    # Iterate along the batches of the TRAINING SET
    for inputs, labels in train_dataloader:
        inputs, labels = inputs.to(device), labels.to(device)

        # Zera os parametros do gradiente
        optimizer.zero_grad()

        # FORWARD
        # ------>
        # Habilita o cálculo do gradiente
        torch.set_grad_enabled(True)

        # Saída do modelo para o lote
        outputs = model(inputs)

        # 'outputs' está em porcentagens. Tomar os máximos como resposta.
        preds = torch.argmax(outputs, dim=1)

        # Calcula a perda (loss)
        loss = criterion(outputs, labels)

        # BACKWARD
        # <-------
        loss.backward()

        # Atualiza os parâmetros da rede
        optimizer.step()

        # Atualiza a perda da época
        loss_epoch_train += loss.item() * inputs.size(0)

        # Atualiza o número de amostras classificadas corretamente na época.
        num_hits_epoch_train += torch.sum(preds == labels.data)

    # Perda desta época
    train_loss = loss_epoch_train / train_size
    # Acurácia desta época
    train_acc = num_hits_epoch_train.double() / train_size

    # Store loss and accuracy in lists
    train_loss_list.append(train_loss)
    train_acc_list.append(train_acc.cpu().item())  # Move para CPU e converte para float

    # VALIDAÇÃO
    # =========================================================================
    model.eval()
    print(f"Validacao - epoca {epoch}")

    # Pego o número de perda e o número de acertos
    loss_epoch_val = 0.0 # Atual perda
    num_hits_epoch_val = 0 # Número de itens corretos

    # Iterate along the batches of the VALIDATION SET
    with torch.no_grad():
        for inputs, labels in val_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)

            # Gero um tensor cujas linhas representam o tamanho do "batch" do input
            outputs = model(inputs)

            # Retorna a maior predição.
            preds = torch.argmax(outputs, dim=1)

            # Calcula a perda (loss)
            loss = criterion(outputs, labels)

            # Atualiza a perda da época
            loss_epoch_val += loss.item() * inputs.size(0)
            # Atualiza os acertos da época
            num_hits_epoch_val += torch.sum(preds == labels.data)

    # Perda e acurácia do conjunto de validação para esta época
    val_loss = loss_epoch_val / val_size
    val_acc = num_hits_epoch_val.double() / val_size

    # Store loss and accuracy in lists
    val_loss_list.append(val_loss)
    val_acc_list.append(val_acc.cpu().item())  # Move para CPU e converte para float

    # Salvar o melhor modelo
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'loss': loss
        }, '/home/cip209/Downloads/Vinícius/Projeto2Visao/Testes/AlexNet/100epocas/checkpoint.pth')

    # Tempo total desta época
    time_epoch = time.time() - time_epoch_start

    # PRINTING
    # --------
    print('Epoch {}/{} - TRAIN Loss: {:.4f} TRAIN Acc: {:.4f} - VAL. Loss: {:.4f} VAL. Acc: {:.4f} ({:.4f} seconds)'.format(epoch, epochs - 1, train_loss, train_acc, val_loss, val_acc, time_epoch))


# Tempo total do treinamento
time_total_train = time.time() - time_total_start

# PRINTING
print('\nTreinamento finalizado. ({0}m and {1}s)'.format(int(time_total_train // 60), int(time_total_train % 60)))
# Out:
# Treinamento - epoca 0
# Validacao - epoca 0
# Epoch 0/99 - TRAIN Loss: 1.8994 TRAIN Acc: 0.3764 - VAL. Loss: 1.6204 VAL. Acc: 0.3797 (46.1742 seconds)
# Treinamento - epoca 1
# Validacao - epoca 1
# Epoch 1/99 - TRAIN Loss: 1.4557 TRAIN Acc: 0.5155 - VAL. Loss: 1.3845 VAL. Acc: 0.5379 (44.9991 seconds)
# Treinamento - epoca 2
# Validacao - epoca 2
# Epoch 2/99 - TRAIN Loss: 1.3250 TRAIN Acc: 0.5505 - VAL. Loss: 1.6622 VAL. Acc: 0.3418 (42.3737 seconds)
# Treinamento - epoca 3
# Validacao - epoca 3
# Epoch 3/99 - TRAIN Loss: 1.2936 TRAIN Acc: 0.5576 - VAL. Loss: 1.3953 VAL. Acc: 0.6115 (44.8829 seconds)
# Treinamento - epoca 4
# Validacao - epoca 4
# Epoch 4/99 - TRAIN Loss: 1.1768 TRAIN Acc: 0.6117 - VAL. Loss: 1.3404 VAL. Acc: 0.5627 (42.0890 seconds)
# Treinamento - epoca 5
# Validacao - epoca 5
# Epoch 5/99 - TRAIN Loss: 1.1429 TRAIN Acc: 0.6027 - VAL. Loss: 1.1802 VAL. Acc: 0.6327 (45.2697 seconds)
# Treinamento - epoca 6
# Validacao - epoca 6
# Epoch 6/99 - TRAIN Loss: 1.0259 TRAIN Acc: 0.6450 - VAL. Loss: 0.9761 VAL. Acc: 0.6749 (45.0558 seconds)
# Treinamento - epoca 7
# Validacao - epoca 7
# Epoch 7/99 - TRAIN Loss: 0.9350 TRAIN Acc: 0.6831 - VAL. Loss: 0.9520 VAL. Acc: 0.6545 (42.8376 seconds)
# Treinamento - epoca 8
# Validacao - epoca 8
# Epoch 8/99 - TRAIN Loss: 0.9426 TRAIN Acc: 0.6760 - VAL. Loss: 0.9458 VAL. Acc: 0.6880 (44.9460 seconds)
# Treinamento - epoca 9
# Validacao - epoca 9
# Epoch 9/99 - TRAIN Loss: 0.9263 TRAIN Acc: 0.6858 - VAL. Loss: 1.4953 VAL. Acc: 0.5787 (42.8673 seconds)
# Treinamento - epoca 10
# Validacao - epoca 10
# Epoch 10/99 - TRAIN Loss: 0.9811 TRAIN Acc: 0.6775 - VAL. Loss: 1.0070 VAL. Acc: 0.6574 (41.8231 seconds)
# Treinamento - epoca 11
# Validacao - epoca 11
# Epoch 11/99 - TRAIN Loss: 1.0840 TRAIN Acc: 0.6415 - VAL. Loss: 0.9618 VAL. Acc: 0.6953 (43.5941 seconds)
# Treinamento - epoca 12
# Validacao - epoca 12
# Epoch 12/99 - TRAIN Loss: 0.8927 TRAIN Acc: 0.7004 - VAL. Loss: 0.8302 VAL. Acc: 0.7172 (44.0976 seconds)
# Treinamento - epoca 13
# Validacao - epoca 13
# Epoch 13/99 - TRAIN Loss: 0.8406 TRAIN Acc: 0.7198 - VAL. Loss: 0.8831 VAL. Acc: 0.6953 (41.8024 seconds)
# Treinamento - epoca 14
# Validacao - epoca 14
# Epoch 14/99 - TRAIN Loss: 0.8391 TRAIN Acc: 0.7112 - VAL. Loss: 0.7744 VAL. Acc: 0.7413 (43.9830 seconds)
# Treinamento - epoca 15
# Validacao - epoca 15
# Epoch 15/99 - TRAIN Loss: 0.7672 TRAIN Acc: 0.7337 - VAL. Loss: 0.7856 VAL. Acc: 0.7442 (43.7824 seconds)
# Treinamento - epoca 16
# Validacao - epoca 16
# Epoch 16/99 - TRAIN Loss: 0.7755 TRAIN Acc: 0.7354 - VAL. Loss: 0.7605 VAL. Acc: 0.7383 (41.6791 seconds)
# Treinamento - epoca 17
# Validacao - epoca 17
# Epoch 17/99 - TRAIN Loss: 0.7445 TRAIN Acc: 0.7447 - VAL. Loss: 0.7976 VAL. Acc: 0.7442 (42.2799 seconds)
# Treinamento - epoca 18
# Validacao - epoca 18
# Epoch 18/99 - TRAIN Loss: 0.7131 TRAIN Acc: 0.7577 - VAL. Loss: 0.7527 VAL. Acc: 0.7456 (43.6000 seconds)
# Treinamento - epoca 19
# Validacao - epoca 19
# Epoch 19/99 - TRAIN Loss: 0.8669 TRAIN Acc: 0.7041 - VAL. Loss: 0.8376 VAL. Acc: 0.7289 (41.4553 seconds)
# Treinamento - epoca 20
# Validacao - epoca 20
# Epoch 20/99 - TRAIN Loss: 0.7848 TRAIN Acc: 0.7431 - VAL. Loss: 0.8731 VAL. Acc: 0.7136 (41.6662 seconds)
# Treinamento - epoca 21
# Validacao - epoca 21
# Epoch 21/99 - TRAIN Loss: 0.7441 TRAIN Acc: 0.7487 - VAL. Loss: 0.7822 VAL. Acc: 0.7507 (46.1597 seconds)
# Treinamento - epoca 22
# Validacao - epoca 22
# Epoch 22/99 - TRAIN Loss: 0.6663 TRAIN Acc: 0.7629 - VAL. Loss: 1.1601 VAL. Acc: 0.6924 (41.4645 seconds)
# Treinamento - epoca 23
# Validacao - epoca 23
# Epoch 23/99 - TRAIN Loss: 0.7772 TRAIN Acc: 0.7435 - VAL. Loss: 0.8747 VAL. Acc: 0.7157 (41.5123 seconds)
# Treinamento - epoca 24
# Validacao - epoca 24
# Epoch 24/99 - TRAIN Loss: 0.7881 TRAIN Acc: 0.7389 - VAL. Loss: 0.8594 VAL. Acc: 0.7310 (42.4521 seconds)
# Treinamento - epoca 25
# Validacao - epoca 25
# Epoch 25/99 - TRAIN Loss: 0.7095 TRAIN Acc: 0.7527 - VAL. Loss: 0.7854 VAL. Acc: 0.7362 (41.3413 seconds)
# Treinamento - epoca 26
# Validacao - epoca 26
# Epoch 26/99 - TRAIN Loss: 0.6875 TRAIN Acc: 0.7687 - VAL. Loss: 0.8715 VAL. Acc: 0.7128 (41.3304 seconds)
# Treinamento - epoca 27
# Validacao - epoca 27
# Epoch 27/99 - TRAIN Loss: 0.6578 TRAIN Acc: 0.7766 - VAL. Loss: 0.8151 VAL. Acc: 0.7449 (41.5999 seconds)
# Treinamento - epoca 28
# Validacao - epoca 28
# Epoch 28/99 - TRAIN Loss: 0.6613 TRAIN Acc: 0.7747 - VAL. Loss: 0.7473 VAL. Acc: 0.7624 (43.5684 seconds)
# Treinamento - epoca 29
# Validacao - epoca 29
# Epoch 29/99 - TRAIN Loss: 0.6097 TRAIN Acc: 0.7868 - VAL. Loss: 0.7912 VAL. Acc: 0.7449 (41.5485 seconds)
# Treinamento - epoca 30
# Validacao - epoca 30
# Epoch 30/99 - TRAIN Loss: 0.5694 TRAIN Acc: 0.7947 - VAL. Loss: 0.8937 VAL. Acc: 0.7478 (41.6280 seconds)
# Treinamento - epoca 31
# Validacao - epoca 31
# Epoch 31/99 - TRAIN Loss: 0.7963 TRAIN Acc: 0.7362 - VAL. Loss: 0.8486 VAL. Acc: 0.7354 (41.2787 seconds)
# Treinamento - epoca 32
# Validacao - epoca 32
# Epoch 32/99 - TRAIN Loss: 0.6385 TRAIN Acc: 0.7791 - VAL. Loss: 0.8053 VAL. Acc: 0.7522 (41.4429 seconds)
# Treinamento - epoca 33
# Validacao - epoca 33
# Epoch 33/99 - TRAIN Loss: 0.5962 TRAIN Acc: 0.7876 - VAL. Loss: 0.8194 VAL. Acc: 0.7587 (41.4530 seconds)
# Treinamento - epoca 34
# Validacao - epoca 34
# Epoch 34/99 - TRAIN Loss: 0.5950 TRAIN Acc: 0.7964 - VAL. Loss: 0.8109 VAL. Acc: 0.7573 (41.4846 seconds)
# Treinamento - epoca 35
# Validacao - epoca 35
# Epoch 35/99 - TRAIN Loss: 0.7995 TRAIN Acc: 0.7358 - VAL. Loss: 0.9121 VAL. Acc: 0.7208 (41.2519 seconds)
# Treinamento - epoca 36
# Validacao - epoca 36
# Epoch 36/99 - TRAIN Loss: 0.6916 TRAIN Acc: 0.7658 - VAL. Loss: 1.4600 VAL. Acc: 0.6327 (41.7426 seconds)
# Treinamento - epoca 37
# Validacao - epoca 37
# Epoch 37/99 - TRAIN Loss: 0.7399 TRAIN Acc: 0.7568 - VAL. Loss: 0.7957 VAL. Acc: 0.7682 (43.8751 seconds)
# Treinamento - epoca 38
# Validacao - epoca 38
# Epoch 38/99 - TRAIN Loss: 0.7328 TRAIN Acc: 0.7529 - VAL. Loss: 0.7980 VAL. Acc: 0.7296 (41.5003 seconds)
# Treinamento - epoca 39
# Validacao - epoca 39
# Epoch 39/99 - TRAIN Loss: 0.6488 TRAIN Acc: 0.7781 - VAL. Loss: 0.8267 VAL. Acc: 0.7325 (41.4719 seconds)
# Treinamento - epoca 40
# Validacao - epoca 40
# Epoch 40/99 - TRAIN Loss: 0.6178 TRAIN Acc: 0.7878 - VAL. Loss: 0.8011 VAL. Acc: 0.7668 (41.4326 seconds)
# Treinamento - epoca 41
# Validacao - epoca 41
# Epoch 41/99 - TRAIN Loss: 0.5485 TRAIN Acc: 0.8097 - VAL. Loss: 0.7768 VAL. Acc: 0.7704 (44.7754 seconds)
# Treinamento - epoca 42
# Validacao - epoca 42
# Epoch 42/99 - TRAIN Loss: 0.5663 TRAIN Acc: 0.8078 - VAL. Loss: 0.6847 VAL. Acc: 0.7770 (43.7203 seconds)
# Treinamento - epoca 43
# Validacao - epoca 43
# Epoch 43/99 - TRAIN Loss: 0.5382 TRAIN Acc: 0.8137 - VAL. Loss: 0.7339 VAL. Acc: 0.7733 (41.2231 seconds)
# Treinamento - epoca 44
# Validacao - epoca 44
# Epoch 44/99 - TRAIN Loss: 0.5357 TRAIN Acc: 0.8139 - VAL. Loss: 0.8090 VAL. Acc: 0.7493 (41.4851 seconds)
# Treinamento - epoca 45
# Validacao - epoca 45
# Epoch 45/99 - TRAIN Loss: 0.6844 TRAIN Acc: 0.7720 - VAL. Loss: 0.7392 VAL. Acc: 0.7719 (41.1376 seconds)
# Treinamento - epoca 46
# Validacao - epoca 46
# Epoch 46/99 - TRAIN Loss: 0.6046 TRAIN Acc: 0.7951 - VAL. Loss: 0.6829 VAL. Acc: 0.7770 (41.0258 seconds)
# Treinamento - epoca 47
# Validacao - epoca 47
# Epoch 47/99 - TRAIN Loss: 0.6501 TRAIN Acc: 0.7874 - VAL. Loss: 0.8945 VAL. Acc: 0.6997 (41.2668 seconds)
# Treinamento - epoca 48
# Validacao - epoca 48
# Epoch 48/99 - TRAIN Loss: 0.6988 TRAIN Acc: 0.7683 - VAL. Loss: 0.7552 VAL. Acc: 0.7566 (42.7540 seconds)
# Treinamento - epoca 49
# Validacao - epoca 49
# Epoch 49/99 - TRAIN Loss: 0.6114 TRAIN Acc: 0.7860 - VAL. Loss: 0.8044 VAL. Acc: 0.7697 (41.6659 seconds)
# Treinamento - epoca 50
# Validacao - epoca 50
# Epoch 50/99 - TRAIN Loss: 0.6415 TRAIN Acc: 0.7824 - VAL. Loss: 0.7260 VAL. Acc: 0.7755 (41.4765 seconds)
# Treinamento - epoca 51
# Validacao - epoca 51
# Epoch 51/99 - TRAIN Loss: 0.5966 TRAIN Acc: 0.7970 - VAL. Loss: 1.0123 VAL. Acc: 0.6618 (41.2374 seconds)
# Treinamento - epoca 52
# Validacao - epoca 52
# Epoch 52/99 - TRAIN Loss: 0.6492 TRAIN Acc: 0.7789 - VAL. Loss: 0.8251 VAL. Acc: 0.7413 (41.3422 seconds)
# Treinamento - epoca 53
# Validacao - epoca 53
# Epoch 53/99 - TRAIN Loss: 0.5639 TRAIN Acc: 0.8035 - VAL. Loss: 0.8177 VAL. Acc: 0.7478 (41.7329 seconds)
# Treinamento - epoca 54
# Validacao - epoca 54
# Epoch 54/99 - TRAIN Loss: 0.5435 TRAIN Acc: 0.8068 - VAL. Loss: 0.7070 VAL. Acc: 0.8047 (43.5768 seconds)
# Treinamento - epoca 55
# Validacao - epoca 55
# Epoch 55/99 - TRAIN Loss: 0.5246 TRAIN Acc: 0.8209 - VAL. Loss: 0.7281 VAL. Acc: 0.7850 (41.1831 seconds)
# Treinamento - epoca 56
# Validacao - epoca 56
# Epoch 56/99 - TRAIN Loss: 0.5760 TRAIN Acc: 0.8078 - VAL. Loss: 0.8126 VAL. Acc: 0.7843 (41.7717 seconds)
# Treinamento - epoca 57
# Validacao - epoca 57
# Epoch 57/99 - TRAIN Loss: 0.5473 TRAIN Acc: 0.8159 - VAL. Loss: 0.7455 VAL. Acc: 0.7631 (41.3636 seconds)
# Treinamento - epoca 58
# Validacao - epoca 58
# Epoch 58/99 - TRAIN Loss: 0.5108 TRAIN Acc: 0.8249 - VAL. Loss: 0.7069 VAL. Acc: 0.7762 (41.3083 seconds)
# Treinamento - epoca 59
# Validacao - epoca 59
# Epoch 59/99 - TRAIN Loss: 0.4962 TRAIN Acc: 0.8322 - VAL. Loss: 0.6988 VAL. Acc: 0.7857 (41.2547 seconds)
# Treinamento - epoca 60
# Validacao - epoca 60
# Epoch 60/99 - TRAIN Loss: 0.6537 TRAIN Acc: 0.7781 - VAL. Loss: 1.3288 VAL. Acc: 0.6640 (41.3410 seconds)
# Treinamento - epoca 61
# Validacao - epoca 61
# Epoch 61/99 - TRAIN Loss: 0.6507 TRAIN Acc: 0.7797 - VAL. Loss: 0.7924 VAL. Acc: 0.7369 (41.1340 seconds)
# Treinamento - epoca 62
# Validacao - epoca 62
# Epoch 62/99 - TRAIN Loss: 0.5509 TRAIN Acc: 0.8082 - VAL. Loss: 0.7037 VAL. Acc: 0.7799 (41.5737 seconds)
# Treinamento - epoca 63
# Validacao - epoca 63
# Epoch 63/99 - TRAIN Loss: 0.4851 TRAIN Acc: 0.8320 - VAL. Loss: 0.9082 VAL. Acc: 0.7464 (41.2198 seconds)
# Treinamento - epoca 64
# Validacao - epoca 64
# Epoch 64/99 - TRAIN Loss: 0.6049 TRAIN Acc: 0.7905 - VAL. Loss: 0.7968 VAL. Acc: 0.7580 (41.4413 seconds)
# Treinamento - epoca 65
# Validacao - epoca 65
# Epoch 65/99 - TRAIN Loss: 0.5257 TRAIN Acc: 0.8203 - VAL. Loss: 0.7377 VAL. Acc: 0.7646 (41.6560 seconds)
# Treinamento - epoca 66
# Validacao - epoca 66
# Epoch 66/99 - TRAIN Loss: 0.4969 TRAIN Acc: 0.8266 - VAL. Loss: 0.7818 VAL. Acc: 0.7952 (41.3087 seconds)
# Treinamento - epoca 67
# Validacao - epoca 67
# Epoch 67/99 - TRAIN Loss: 0.4621 TRAIN Acc: 0.8364 - VAL. Loss: 0.9521 VAL. Acc: 0.7668 (42.1406 seconds)
# Treinamento - epoca 68
# Validacao - epoca 68
# Epoch 68/99 - TRAIN Loss: 0.7027 TRAIN Acc: 0.7841 - VAL. Loss: 0.7511 VAL. Acc: 0.7668 (41.2067 seconds)
# Treinamento - epoca 69
# Validacao - epoca 69
# Epoch 69/99 - TRAIN Loss: 0.5674 TRAIN Acc: 0.8003 - VAL. Loss: 0.8079 VAL. Acc: 0.7544 (41.3070 seconds)
# Treinamento - epoca 70
# Validacao - epoca 70
# Epoch 70/99 - TRAIN Loss: 0.7258 TRAIN Acc: 0.7672 - VAL. Loss: 0.7063 VAL. Acc: 0.7675 (41.4649 seconds)
# Treinamento - epoca 71
# Validacao - epoca 71
# Epoch 71/99 - TRAIN Loss: 0.5603 TRAIN Acc: 0.8085 - VAL. Loss: 0.8078 VAL. Acc: 0.7770 (41.1515 seconds)
# Treinamento - epoca 72
# Validacao - epoca 72
# Epoch 72/99 - TRAIN Loss: 0.5609 TRAIN Acc: 0.8074 - VAL. Loss: 0.8950 VAL. Acc: 0.7755 (41.4437 seconds)
# Treinamento - epoca 73
# Validacao - epoca 73
# Epoch 73/99 - TRAIN Loss: 0.4834 TRAIN Acc: 0.8278 - VAL. Loss: 0.7868 VAL. Acc: 0.7733 (41.4269 seconds)
# Treinamento - epoca 74
# Validacao - epoca 74
# Epoch 74/99 - TRAIN Loss: 0.5615 TRAIN Acc: 0.8176 - VAL. Loss: 0.7527 VAL. Acc: 0.7777 (41.2094 seconds)
# Treinamento - epoca 75
# Validacao - epoca 75
# Epoch 75/99 - TRAIN Loss: 0.5259 TRAIN Acc: 0.8126 - VAL. Loss: 0.8172 VAL. Acc: 0.7726 (41.5288 seconds)
# Treinamento - epoca 76
# Validacao - epoca 76
# Epoch 76/99 - TRAIN Loss: 0.7102 TRAIN Acc: 0.7645 - VAL. Loss: 0.7538 VAL. Acc: 0.7595 (41.7072 seconds)
# Treinamento - epoca 77
# Validacao - epoca 77
# Epoch 77/99 - TRAIN Loss: 0.6702 TRAIN Acc: 0.7787 - VAL. Loss: 0.9349 VAL. Acc: 0.7165 (41.5006 seconds)
# Treinamento - epoca 78
# Validacao - epoca 78
# Epoch 78/99 - TRAIN Loss: 0.5740 TRAIN Acc: 0.7980 - VAL. Loss: 0.8197 VAL. Acc: 0.7741 (41.4684 seconds)
# Treinamento - epoca 79
# Validacao - epoca 79
# Epoch 79/99 - TRAIN Loss: 0.5222 TRAIN Acc: 0.8226 - VAL. Loss: 0.8087 VAL. Acc: 0.7536 (41.4611 seconds)
# Treinamento - epoca 80
# Validacao - epoca 80
# Epoch 80/99 - TRAIN Loss: 0.4815 TRAIN Acc: 0.8370 - VAL. Loss: 0.7589 VAL. Acc: 0.7646 (41.2843 seconds)
# Treinamento - epoca 81
# Validacao - epoca 81
# Epoch 81/99 - TRAIN Loss: 0.4747 TRAIN Acc: 0.8334 - VAL. Loss: 0.8660 VAL. Acc: 0.7835 (41.1574 seconds)
# Treinamento - epoca 82
# Validacao - epoca 82
# Epoch 82/99 - TRAIN Loss: 0.4001 TRAIN Acc: 0.8613 - VAL. Loss: 0.7446 VAL. Acc: 0.7879 (41.5274 seconds)
# Treinamento - epoca 83
# Validacao - epoca 83
# Epoch 83/99 - TRAIN Loss: 0.4284 TRAIN Acc: 0.8468 - VAL. Loss: 0.8848 VAL. Acc: 0.7813 (41.1768 seconds)
# Treinamento - epoca 84
# Validacao - epoca 84
# Epoch 84/99 - TRAIN Loss: 0.4407 TRAIN Acc: 0.8455 - VAL. Loss: 0.7179 VAL. Acc: 0.7988 (41.1536 seconds)
# Treinamento - epoca 85
# Validacao - epoca 85
# Epoch 85/99 - TRAIN Loss: 0.4182 TRAIN Acc: 0.8574 - VAL. Loss: 0.9175 VAL. Acc: 0.7267 (41.6151 seconds)
# Treinamento - epoca 86
# Validacao - epoca 86
# Epoch 86/99 - TRAIN Loss: 0.5358 TRAIN Acc: 0.8220 - VAL. Loss: 0.7683 VAL. Acc: 0.7813 (41.1564 seconds)
# Treinamento - epoca 87
# Validacao - epoca 87
# Epoch 87/99 - TRAIN Loss: 0.4909 TRAIN Acc: 0.8303 - VAL. Loss: 0.8234 VAL. Acc: 0.7806 (41.2400 seconds)
# Treinamento - epoca 88
# Validacao - epoca 88
# Epoch 88/99 - TRAIN Loss: 0.5416 TRAIN Acc: 0.8222 - VAL. Loss: 0.9681 VAL. Acc: 0.7675 (41.2582 seconds)
# Treinamento - epoca 89
# Validacao - epoca 89
# Epoch 89/99 - TRAIN Loss: 0.4849 TRAIN Acc: 0.8370 - VAL. Loss: 0.8858 VAL. Acc: 0.7799 (41.3550 seconds)
# Treinamento - epoca 90
# Validacao - epoca 90
# Epoch 90/99 - TRAIN Loss: 0.5536 TRAIN Acc: 0.8255 - VAL. Loss: 0.7433 VAL. Acc: 0.7806 (41.0587 seconds)
# Treinamento - epoca 91
# Validacao - epoca 91
# Epoch 91/99 - TRAIN Loss: 0.6484 TRAIN Acc: 0.8012 - VAL. Loss: 0.9835 VAL. Acc: 0.7150 (41.4190 seconds)
# Treinamento - epoca 92
# Validacao - epoca 92
# Epoch 92/99 - TRAIN Loss: 0.9452 TRAIN Acc: 0.7087 - VAL. Loss: 0.7868 VAL. Acc: 0.7682 (41.1911 seconds)
# Treinamento - epoca 93
# Validacao - epoca 93
# Epoch 93/99 - TRAIN Loss: 0.5670 TRAIN Acc: 0.8128 - VAL. Loss: 0.7274 VAL. Acc: 0.7872 (41.2798 seconds)
# Treinamento - epoca 94
# Validacao - epoca 94
# Epoch 94/99 - TRAIN Loss: 0.4500 TRAIN Acc: 0.8434 - VAL. Loss: 0.7364 VAL. Acc: 0.7886 (41.2409 seconds)
# Treinamento - epoca 95
# Validacao - epoca 95
# Epoch 95/99 - TRAIN Loss: 0.4323 TRAIN Acc: 0.8578 - VAL. Loss: 0.6775 VAL. Acc: 0.7784 (41.7548 seconds)
# Treinamento - epoca 96
# Validacao - epoca 96
# Epoch 96/99 - TRAIN Loss: 0.5739 TRAIN Acc: 0.8095 - VAL. Loss: 0.7371 VAL. Acc: 0.7864 (41.5413 seconds)
# Treinamento - epoca 97
# Validacao - epoca 97
# Epoch 97/99 - TRAIN Loss: 0.4258 TRAIN Acc: 0.8522 - VAL. Loss: 0.7606 VAL. Acc: 0.7988 (41.2680 seconds)
# Treinamento - epoca 98
# Validacao - epoca 98
# Epoch 98/99 - TRAIN Loss: 0.4354 TRAIN Acc: 0.8524 - VAL. Loss: 0.7204 VAL. Acc: 0.7806 (41.1832 seconds)
# Treinamento - epoca 99
# Validacao - epoca 99
# Epoch 99/99 - TRAIN Loss: 0.4332 TRAIN Acc: 0.8538 - VAL. Loss: 0.8043 VAL. Acc: 0.7726 (41.4399 seconds)
#
# Treinamento finalizado. (70m and 1s)

# %% [markdown]
# #Analisando o Treinamento

# %%
# Lista com os índices das épocas. [0, 1, ... num_epochs - 1]
epochs_list = list(range(len(train_loss_list)))

# Títulos
loss_title = f'Loss over {len(epochs_list)} Epochs'
acc_title = f'Accuracy over {len(epochs_list)} Epochs'

# Plot - Loss and Accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot - Loss
ax1.set_title(loss_title)
ax1.plot(epochs_list, train_loss_list, c='magenta', ls='--', label='Train Loss', fillstyle='none')
ax1.plot(epochs_list, val_loss_list, c='green', ls='--', label='Val. Loss', fillstyle='none')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend(loc='best')
ax1.grid(True)

# Plot - Accuracy
ax2.set_title(acc_title)
ax2.plot(epochs_list, train_acc_list, c='magenta', ls='-', label='Train Accuracy', fillstyle='none')
ax2.plot(epochs_list, val_acc_list, c='green', ls='-', label='Val. Accuracy', fillstyle='none')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend(loc='best')
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Avaliando o Modelo

# %%
# Carregando o modelo Pré-Treinado
model = models.alexnet(pretrained=False)

# Altera o número de neurônios na cadama de saída.
model.classifier[6] = nn.Linear(model.classifier[6].in_features, num_classes)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

model.to(device)

# Carregar o melhor modelo salvo
checkpoint = torch.load('/home/cip209/Downloads/Vinícius/Projeto2Visao/Testes/AlexNet/100epocas/checkpoint.pth')
model.load_state_dict(checkpoint['model_state_dict'])
start_epoch = checkpoint['epoch']

print(f"Melhor Época {start_epoch}")


model.eval()

# Lista com as classes reais e classes preditas
true_test_list = []
pred_test_list = []
# Lista com as probabilidades
prob_test_list = []

# Iterate along the batches of the TEST SET
with torch.no_grad():
    for img_list, labelList in test_dataloader:
        img_list, labelList = img_list.to(device), labelList.to(device)

        # -----> FORWARD
        # Saída do modelo
        outputs = model(img_list)

        # Predição
        preds = torch.argmax(outputs, dim=1)

        # Calcula probabilidades
        outputs_prob = nn.functional.softmax(outputs, dim=1)
        prob_test_batch = outputs_prob.cpu().numpy()

        # Classes reais (true) e classes preditas (pred) para este lote.
        true_test_batch = labelList.cpu().numpy()
        pred_test_batch = preds.cpu().numpy()

        # Adiciona os resultados às listas
        true_test_list.extend(true_test_batch)
        pred_test_list.extend(pred_test_batch)
        prob_test_list.extend(prob_test_batch)
# Out:
# /home/cip209/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/cip209/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Using device: cuda
# /tmp/ipykernel_8322/1524566263.py:13: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/home/cip209/Downloads/Vinícius/Projeto2Visao/Testes/AlexNet/100epocas/checkpoint.pth')
# Melhor Época 54

# %% [markdown]
# # Matrix de Confusão e Relatório de Classificação

# %%
# Matriz de Confusão
conf_mat_test = metrics.confusion_matrix(true_test_list, pred_test_list)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat_test, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Matriz de Confusão')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Classification report - Scikit-learn
class_rep_test = metrics.classification_report(true_test_list, pred_test_list,
                                              target_names=class_names, output_dict = True, #dicionário para uso pessoal
                                              digits=4,
                                              zero_division=0)
print('\nClass. report (test)')
print(class_rep_test)

print("Relatório de Classificação por Classe:")
print(metrics.classification_report(true_test_list, pred_test_list,
                                    target_names=class_names,
                                    digits=4, zero_division=0))

# Accuracy
acc_test = metrics.accuracy_score(true_test_list, pred_test_list)
print('\n\Test Acc.: {:.4f}'.format(acc_test))

# Função para mostrar imagens
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.axis('off')

# Obter um lote de dados de teste
inputs, classes = next(iter(test_dataloader))

# Fazer previsões
outputs = model(inputs.to(device))
_, preds = torch.max(outputs, 1)

# Plotar as imagens e suas previsões
plt.figure(figsize=(15, 10))
for i in range(min(len(inputs), 8)):  # Mostrar até 8 imagens
    ax = plt.subplot(2, 4, i + 1)
    imshow(inputs[i], title=f'Pred: {class_names[preds[i]]}\nTrue: {class_names[classes[i]]}')
plt.tight_layout()
plt.show()


#POR CLASSE
#extração de métricas
precisoes=[class_rep_test[cls]['precision'] for cls in class_names]
recalls=[class_rep_test[cls]['recall'] for cls in class_names]
f1_scores=[class_rep_test[cls]['f1-score'] for cls in class_names]

#para plotagem
x = range(len(class_names))
width = 0.2 #largura barras

plt.figure(figsize=(12, 6))
plt.bar(x, precisoes, width, label='Precisão', color='blue')
plt.bar([i + width for i in x], recalls, width, label='Recall', color='green')
plt.bar([i + 2 * width for i in x], f1_scores, width, label='F1-Score', color='orange')

#dos eixos
plt.xlabel('Classes')
plt.ylabel('Métricas')
plt.title('Métricas por Classe')
plt.xticks([i + width for i in x], class_names, rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

#CURVA ROC
true_binarized = label_binarize(true_test_list, classes=list(range(num_classes)))

#variaveis para curvas e areas
fpr = dict()
tpr = dict()
roc_auc = dict()

#calcular curva roc e auc para cada classe
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(true_binarized[:, i], [p[i] for p in prob_test_list])
    roc_auc[i] = auc(fpr[i], tpr[i])

#calcular marcro-average roc e auc
fpr["macro"], tpr["macro"], _=roc_curve(
    true_binarized.ravel(), [p for probs in prob_test_list for p in probs]
)

roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

#plotar curvas roc para cada classe
plt.figure(figsize=(10, 8))
colors = plt.cm.get_cmap("tab10", num_classes)

"""
for i in range(num_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        color=colors(i),
        lw=2,
        label=f"Classe {class_names[i]} (AUC = {roc_auc[i]:0.2f})",
    )
"""

# Adicionar curva macro-average
plt.plot(
    fpr["macro"],
    tpr["macro"],
    color="darkorange",
    linestyle="--",
    lw=3,
    label=f"Macro-average (AUC = {roc_auc['macro']:0.2f})",
)

# Configurar o gráfico
plt.plot([0, 1], [0, 1], color="navy", linestyle="--", lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("Taxa de Falsos Positivos (FPR)")
plt.ylabel("Taxa de Verdadeiros Positivos (TPR)")
plt.title("Curvas ROC para cada classe")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# Class. report (test)
# {'dew': {'precision': 0.9701492537313433, 'recall': 0.8783783783783784, 'f1-score': 0.9219858156028369, 'support': 74.0}, 'fogsmog': {'precision': 0.75, 'recall': 0.9375, 'f1-score': 0.8333333333333334, 'support': 80.0}, 'frost': {'precision': 0.6304347826086957, 'recall': 0.6744186046511628, 'f1-score': 0.651685393258427, 'support': 43.0}, 'glaze': {'precision': 0.5961538461538461, 'recall': 0.6078431372549019, 'f1-score': 0.6019417475728155, 'support': 51.0}, 'hail': {'precision': 0.8529411764705882, 'recall': 0.8529411764705882, 'f1-score': 0.8529411764705882, 'support': 68.0}, 'lightining': {'precision': 0.975609756097561, 'recall': 1.0, 'f1-score': 0.9876543209876543, 'support': 40.0}, 'rain': {'precision': 0.7647058823529411, 'recall': 0.6842105263157895, 'f1-score': 0.7222222222222222, 'support': 57.0}, 'rainbow': {'precision': 1.0, 'recall': 0.896551724137931, 'f1-score': 0.9454545454545454, 'support': 29.0}, 'rime': {'precision': 0.8362068965517241, 'recall': 0.8738738738738738, 'f1-score': 0.8546255506607929, 'support': 111.0}, 'sandstorm': {'precision': 0.8783783783783784, 'recall': 0.8666666666666667, 'f1-score': 0.87248322147651, 'support': 75.0}, 'snow': {'precision': 0.6956521739130435, 'recall': 0.5423728813559322, 'f1-score': 0.6095238095238096, 'support': 59.0}, 'accuracy': 0.8107714701601164, 'macro avg': {'precision': 0.8136574678416474, 'recall': 0.8013415426459296, 'f1-score': 0.8048955578694122, 'support': 687.0}, 'weighted avg': {'precision': 0.8131834560067668, 'recall': 0.8107714701601164, 'f1-score': 0.809268881918411, 'support': 687.0}}
# Relatório de Classificação por Classe:
#               precision    recall  f1-score   support
#
#          dew     0.9701    0.8784    0.9220        74
#      fogsmog     0.7500    0.9375    0.8333        80
#        frost     0.6304    0.6744    0.6517        43
#        glaze     0.5962    0.6078    0.6019        51
#         hail     0.8529    0.8529    0.8529        68
#   lightining     0.9756    1.0000    0.9877        40
#         rain     0.7647    0.6842    0.7222        57
#      rainbow     1.0000    0.8966    0.9455        29
#         rime     0.8362    0.8739    0.8546       111
#    sandstorm     0.8784    0.8667    0.8725        75
#         snow     0.6957    0.5424    0.6095        59
#
#     accuracy                         0.8108       687
#    macro avg     0.8137    0.8013    0.8049       687
# weighted avg     0.8132    0.8108    0.8093       687
#
#
# \Test Acc.: 0.8108
# /tmp/ipykernel_8322/961682266.py:101: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab10", num_classes)

# %% [markdown]
# #Créditos

# %%
https://github.com/joaofmari/awesome-computer-vision-deep-learning
